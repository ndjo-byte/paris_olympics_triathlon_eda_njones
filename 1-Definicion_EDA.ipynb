# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Paris Olympics Triathlon Analysis"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = ""

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "Siendo la parte más larga de la carrera, montar bicicleta será la disciplina más importante"

# %%
# Escribe más hipótesis si las hubiera en Markdown
hipotesis_2 = "La edad del competidor también influye en la posición del atleta, dado a la experiencia que aporta."
hipotesis_3 = "Atletas de Francia en general acaban en mejor posición, dado al ventaja que aporta competir en su proprio país."
hipotesis_4 = "Calificación mundial (anterior) es buena forma de predecir el resultado de la carrera olympica"

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd

# %%
# guarda en variables los datasets y su fuente
df_1 = pd.read_csv('./paris_olympics_datasets/athletes.csv')
fuente_1 = "Kaggle"

df_2 = pd.read_csv('./paris_olympics_datasets/results/triathlon.csv')
fuente_2 = "Kaggle"

df_3 = pd.read_csv('./paris_olympics_datasets/results/Results for Elite Men - Paris 2024 Olympic Games.csv')
fuente_3 = "World Triathlon .org"

df_4 = pd.read_csv('./paris_olympics_datasets/results/Results for Elite Women - Paris 2024 Olympic Games.csv')
fuente_4 = "World Triathlon .org"

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df_1.head()
# Out:
#       code  current               name     name_short            name_tv  \
# 0  1532872     True   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN
# 1  1532873     True     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN
# 2  1532874     True    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN
# 3  1532944     True  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN
# 4  1532945     True    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN
#
#   gender function country_code  country country_long  ...  \
# 0   Male  Athlete          ARM  Armenia      Armenia  ...
# 1   Male  Athlete          ARM  Armenia      Armenia  ...
# 2   Male  Athlete          ARM  Armenia      Armenia  ...
# 3   Male  Athlete          ARM  Armenia      Armenia  ...
# 4   Male  Athlete          ARM  Armenia      Armenia  ...
#
#                                               family  \
# 0                          Father, Gevorg Aleksanyan
# 1                                                NaN
# ...

# %%
# Siguiente dataset...
df_2.head()
# Out:
#                         date                          stage_code   event_code  \
# 0  2024-07-31T12:48:33+02:00  TRIMOLYMPIC-----------FNL-000100--  TRIMOLYMPIC
# 1  2024-07-31T12:48:33+02:00  TRIMOLYMPIC-----------FNL-000100--  TRIMOLYMPIC
# 2  2024-07-31T12:48:33+02:00  TRIMOLYMPIC-----------FNL-000100--  TRIMOLYMPIC
# 3  2024-07-31T12:48:33+02:00  TRIMOLYMPIC-----------FNL-000100--  TRIMOLYMPIC
# 4  2024-07-31T12:48:33+02:00  TRIMOLYMPIC-----------FNL-000100--  TRIMOLYMPIC
#
#          event_name       event_stage             stage gender  \
# 0  Men's Individual  Men's Individual  Men's Individual      M
# 1  Men's Individual  Men's Individual  Men's Individual      M
# 2  Men's Individual  Men's Individual  Men's Individual      M
# 3  Men's Individual  Men's Individual  Men's Individual      M
# 4  Men's Individual  Men's Individual  Men's Individual      M
#
#   discipline_name discipline_code               venue  ... participant_type  \
# ...

# %%
# Siguiente dataset...
df_3.head()
# Out:
#    Program ID  Athlete ID Athlete First Name Athlete Last Name Country  \
# 0      655047       96742               Alex               Yee     GBR
# 1      655047      104034             Hayden             Wilde     NZL
# 2      655047       63162                Léo           Bergere     FRA
# 3      655047       30249             Pierre          Le Corre     FRA
# 4      655047       86042              Vasco            Vilaca     POR
#
#    Start Number      Swim        T1      Bike        T2       Run  Position  \
# 0            56  00:20:37  00:00:50  00:51:57  00:00:22  00:29:47       1.0
# 1            21  00:21:13  00:00:50  00:51:20  00:00:27  00:29:49       2.0
# 2            27  00:20:37  00:00:51  00:51:55  00:00:25  00:29:55       3.0
# 3            29  00:20:20  00:00:51  00:52:14  00:00:25  00:30:01       4.0
# 4            48  00:21:03  00:00:52  00:51:30  00:00:27  00:30:04       5.0
#
#   Status Total Time
# 0    NaN   01:43:33
# 1    NaN   01:43:39
# ...

# %%
# Siguiente dataset...
df_4.head()
# Out:
#    Program ID  Athlete ID Athlete First Name Athlete Last Name Country  \
# 0      655048       63163          Cassandre         Beaugrand     FRA
# 1      655048       84816              Julie            Derron     SUI
# 2      655048      117212               Beth            Potter     GBR
# 3      655048      125375               Emma          Lombardi     FRA
# 4      655048        7776              Flora             Duffy     BER
#
#    Start Number      Swim        T1      Bike        T2       Run  Position  \
# 0            33  00:22:32  00:00:53  00:58:20  00:00:28  00:32:42       1.0
# 1             7  00:22:51  00:00:54  00:57:58  00:00:27  00:32:51       2.0
# 2            25  00:22:25  00:00:54  00:58:26  00:00:26  00:32:59       3.0
# 3            34  00:22:36  00:00:56  00:58:12  00:00:27  00:33:05       4.0
# 4            44  00:22:05  00:00:56  00:58:44  00:00:28  00:33:59       5.0
#
#   Status Total Time
# 0    NaN   01:54:55
# 1    NaN   01:55:01
# ...
